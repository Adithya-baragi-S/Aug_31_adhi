# %% [markdown]
# <a href="https://colab.research.google.com/github/Adithya-baragi-S/Aug_31_adhi/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+6
# Out:
# 8

# %%
pip install instaloader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for instaloader: filename=instaloader-4.9.6-py3-none-any.whl size=62308 sha256=9fa121e44ab8bf5860d24f2688de1ca9865f6bf116e51ffc417580c189829196
#   Stored in directory: /root/.cache/pip/wheels/b4/14/ec/7606499df2201abd28a19573fe2a3488639792d46aad5600f3
# Successfully built instaloader
# ...

# %%
import instaloder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-4fa9e84c4889> in <cell line: 1>()
# ----> 1 import instaloder
#
# ModuleNotFoundError: No module named 'instaloder'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import instaloader

# %%
print(dir(instaloader))
# Out:
# ['AbortDownloadException', 'BadCredentialsException', 'BadResponseException', 'ConnectionException', 'FrozenNodeIterator', 'Hashtag', 'Highlight', 'IPhoneSupportDisabledException', 'Instaloader', 'InstaloaderContext', 'InstaloaderException', 'InvalidArgumentException', 'LatestStamps', 'LoginRequiredException', 'NodeIterator', 'Post', 'PostChangedException', 'PostComment', 'PostCommentAnswer', 'PostLocation', 'PostSidecarNode', 'PrivateProfileNotFollowedException', 'Profile', 'ProfileHasNoPicsException', 'ProfileNotExistsException', 'QueryReturnedBadRequestException', 'QueryReturnedForbiddenException', 'QueryReturnedNotFoundException', 'RateController', 'Story', 'StoryItem', 'TooManyRequestsException', 'TopSearchResults', 'TwoFactorAuthRequiredException', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'exceptions', 'get_json_structure', 'instaloader', 'instaloadercontext', 'lateststamps', 'load_struc
# ...

# %%
a=instaloader.Instaloader()
print(a)

# %%
a=instaloader.Instaloader()
a.download_profile('iamkarthi._.007')
# Out:
# HTTP redirect from https://i.instagram.com/api/v1/users/web_profile_info/?username=iamkarthi._.007 to https://i.instagram.com/accounts/login/?next=/api/v1/users/web_profile_info/
# ---------------------------------------------------------------------------
# LoginRequiredException                    Traceback (most recent call last)
# <ipython-input-9-b8e046994810> in <cell line: 2>()
#       1 a=instaloader.Instaloader()
# ----> 2 a.download_profile('iamkarthi._.007')
#
# /usr/local/lib/python3.10/dist-packages/instaloader/instaloader.py in download_profile(self, profile_name, profile_pic, profile_pic_only, fast_update, download_stories, download_stories_only, download_tagged, download_tagged_only, post_filter, storyitem_filter)
#    1500         # and update name and json data if necessary
#    1501         if isinstance(profile_name, str):
# -> 1502             profile = self.check_profile_id(profile_name.lower())
#    1503         else:
# ...

# %%
a=instaloader.Instaloader()
a.download_profile('adithya_baragi_806')
# Out:
# HTTP redirect from https://i.instagram.com/api/v1/users/web_profile_info/?username=adithya_baragi_806 to https://i.instagram.com/accounts/login/?next=/api/v1/users/web_profile_info/
# ---------------------------------------------------------------------------
# LoginRequiredException                    Traceback (most recent call last)
# <ipython-input-10-b4115a69e699> in <cell line: 2>()
#       1 a=instaloader.Instaloader()
# ----> 2 a.download_profile('adithya_baragi_806')
#
# /usr/local/lib/python3.10/dist-packages/instaloader/instaloader.py in download_profile(self, profile_name, profile_pic, profile_pic_only, fast_update, download_stories, download_stories_only, download_tagged, download_tagged_only, post_filter, storyitem_filter)
#    1500         # and update name and json data if necessary
#    1501         if isinstance(profile_name, str):
# -> 1502             profile = self.check_profile_id(profile_name.lower())
#    1503         else:
# ...

# %%
a.download_profiles('nayana.nagrajofficial')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-f567438285a2> in <cell line: 1>()
# ----> 1 a.download_profiles('nayana.nagrajofficial')
#
# /usr/local/lib/python3.10/dist-packages/instaloader/instaloader.py in download_profiles(self, profiles, profile_pic, posts, tagged, igtv, highlights, stories, fast_update, post_filter, storyitem_filter, raise_errors, latest_stamps)
#    1417
#    1418         for i, profile in enumerate(profiles, start=1):
# -> 1419             self.context.log("[{0:{w}d}/{1:{w}d}] Downloading profile {2}".format(i, len(profiles), profile.username,
#    1420                                                                                   w=len(str(len(profiles)))))
#    1421             with error_handler(profile.username):  # type: ignore # (ignore type for Python 3.5 support)
#
# ...

# %%
a=instaloader.Instaloader()
a.download_profile("nayana.nagrajofficial")
# Out:
# HTTP redirect from https://i.instagram.com/api/v1/users/web_profile_info/?username=nayana.nagrajofficial to https://i.instagram.com/accounts/login/?next=/api/v1/users/web_profile_info/
# ---------------------------------------------------------------------------
# LoginRequiredException                    Traceback (most recent call last)
# <ipython-input-12-67f29aca005a> in <cell line: 2>()
#       1 a=instaloader.Instaloader()
# ----> 2 a.download_profile("nayana.nagrajofficial")
#
# /usr/local/lib/python3.10/dist-packages/instaloader/instaloader.py in download_profile(self, profile_name, profile_pic, profile_pic_only, fast_update, download_stories, download_stories_only, download_tagged, download_tagged_only, post_filter, storyitem_filter)
#    1500         # and update name and json data if necessary
#    1501         if isinstance(profile_name, str):
# -> 1502             profile = self.check_profile_id(profile_name.lower())
#    1503         else:
# ...

# %%
import random

# %%
help(random)
# Out:
# Help on module random:
#
# NAME
#     random - Random variable generators.
#
# MODULE REFERENCE
#     https://docs.python.org/3.10/library/random.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#         bytes
#         -----
#                uniform bytes (values between 0 and 255)
#
#         integers
#         --------
#                uniform within range
#
#         sequences
#         ---------
#                pick random element
#                pick random sample
#                pick weighted random sample
#                generate random permutation
#
#         distributions on the real line:
#         ------------------------------
#                uniform
# ...

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
d=random.randint(1,10)
print(d)
# Out:
# 4

# %%
for i in range(5):
  print(i)
  print(random.randint(1000,9999))
# Out:
# 0
# 5165
# 1
# 2171
# 2
# 3947
# 3
# 5038
# 4
# 5615

# %%
import time

# %%
help(time)
# Out:
# Help on built-in module time:
#
# NAME
#     time - This module provides various functions to manipulate time values.
#
# DESCRIPTION
#     There are two standard representations of time.  One is the number
#     of seconds since the Epoch, in UTC (a.k.a. GMT).  It may be an integer
#     or a floating point number (to represent fractions of seconds).
#     The Epoch is system-defined; on Unix, it is generally January 1st, 1970.
#     The actual value can be retrieved by calling gmtime(0).
#
#     The other representation is a tuple of 9 integers giving local time.
#     The tuple items are:
#       year (including century, e.g. 1998)
#       month (1-12)
#       day (1-31)
#       hours (0-23)
#       minutes (0-59)
#       seconds (0-59)
#       weekday (0-6, Monday is 0)
#       Julian day (day in the year, 1-366)
#       DST (Daylight Savings Time) flag (-1, 0 or 1)
#     If the DST flag is 0, the time is given in the regular time zone;
# ...

# %%
for i in range(5):
  print(i)
  print(random.randint(1000,9999))
  time.sleep(4)
# Out:
# 0
# 3073
# 1
# 6371
# 2
# 8291
# 3
# 7839
# 4
# 3638

# %%
#number guessing game
import random
#generate a random number
n=random.randint(1,10)
guess=int(input("enter a no in 1-10"))
#print(guess)
while n!=guess:
  if guess<n:
    print("too low")
    guess=int(input("enter the no again"))
  elif guess>n:
      print("oop a hiher no")
      guess=int(input("enter the no again"))
print("bingo")
# Out:
# enter a no in 1-102
# too low
# enter the no again3
# bingo

# %%
pip install PyQRCode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for PyQRCode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36228 sha256=eceb200fc3b89fa3b9b29ac98ababe6089c381c95c80d0deccc8381733b6bf15
#   Stored in directory: /root/.cache/pip/wheels/34/2d/20/082874e49a32cdcc87ebaf99dd0099fb7774ef30f010dfb6f2
# Successfully built PyQRCode
# ...

# %%
pip install pypng
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 6.8 MB/s eta 0:00:00
# ...

# %%
import pyqrcode
import png
#give the link which you need to create qrcode
link="https://colab.research.google.com/drive/11YWfsJoDLh790MIjkuL8HNmqIh8jJk08#scrollTo=yEA9k1nbbhHm"
#create a qrcode for above link
qr_code=pyqrcode.create(link)
print(qr_code)
qr_code.png("link.png",scale=8)
# Out:
# QRCode(content=b'https://colab.research.google.com/drive/11YWfsJoDLh790MIjkuL8HNmqIh8jJk08#scrollTo=yEA9k1nbbhHm', error='H', version=9, mode='binary')

# %%
pip install segno
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 6.8 MB/s eta 0:00:00
# ...

# %%
import segno
#print(dir(segno))
#we will use helpers from segno
from segno import helpers
#lets use helpers which includes make_mccard
qr=helpers.make_mecard(name="adithya",
                    email="adithya@gmail.com",
                    phone="+91 7760759896",)
qr.save("myqr.png",scale=8)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
pip install gTTS

# %%
#gtts=google text to sppech
from gtts import gTTS
text=gTTS("hi adithya")
text=gTTS("adithya baragi is ur full name",lang="fr",tld="fr")
text.save("my.mp3")
text.save("my.mp3")
